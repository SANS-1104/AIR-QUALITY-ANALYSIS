# %% [markdown]
# # <center> **`AIR QUALITY ANALYSIS`** </center>

# %% [markdown]
# ### **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ### **Importing dataset**

# %%
data = pd.read_csv("city_day.csv")
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %% [markdown]
# ### **Top 5 data**

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
data.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %% [markdown]
# ### **Data Structure**

# %%
print(f'Total rows: {data.shape[0]}\nTotal Cols : {data.shape[1]}')
# Out:
# Total rows: 29531
# Total Cols : 16

# %% [markdown]
# ### **Information of data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# ### **Finding Null Values**

# %%
data.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# ### **Filling null values**

# %%
columns_to_fill = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
for column in columns_to_fill:
    data[column] = data[column].fillna(data[column].mean())

# %%
bins = [0, 50, 100, 200, 300, 400, float('inf')]  # AQI ranges
labels = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']  # AQI categories

data.loc[data['AQI_Bucket'].isnull(), 'AQI_Bucket'] = pd.cut(
    data.loc[data['AQI_Bucket'].isnull(), 'AQI'], bins=bins, labels=labels, right=False
)

print(data[['AQI', 'AQI_Bucket']].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AQI         29531 non-null  float64
#  1   AQI_Bucket  29531 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 461.6+ KB
# None

# %% [markdown]
# ### **Check if there any null value after filling nan**

# %%
data.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %% [markdown]
# ### **Ensure 'date' is a datetime type**

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %% [markdown]
# ### **add row for year and month**

# %%
data['Month'] = data['Date'].dt.strftime('%b')
data['Year'] = data['Date'].dt.year

# %% [markdown]
# ### **Verify column**

# %%
data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket', 'Month',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ### **Describing the data**

# %%
data.describe()
# Out:
#                                 Date         PM2.5          PM10           NO  \
# count                          29531  29531.000000  29531.000000  29531.00000
# mean   2018-05-14 05:40:15.807118080     67.450578    118.127103     17.57473
# min              2015-01-01 00:00:00      0.040000      0.010000      0.02000
# 25%              2017-04-16 00:00:00     32.150000     79.315000      6.21000
# 50%              2018-08-05 00:00:00     58.030000    118.127103     11.53000
# 75%              2019-09-03 00:00:00     72.450000    118.127103     17.57473
# max              2020-07-01 00:00:00    949.990000   1000.000000    390.68000
# std                              NaN     59.414476     71.500953     21.35922
#
#                 NO2           NOx           NH3            CO           SO2  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      28.560659     32.309123     23.483476      2.248598     14.531977
# ...

# %%
data.head()
# Out:
#         City       Date      PM2.5        PM10     NO    NO2    NOx  \
# 0  Ahmedabad 2015-01-01  67.450578  118.127103   0.92  18.22  17.15
# 1  Ahmedabad 2015-01-02  67.450578  118.127103   0.97  15.69  16.46
# 2  Ahmedabad 2015-01-03  67.450578  118.127103  17.40  19.30  29.70
# 3  Ahmedabad 2015-01-04  67.450578  118.127103   1.70  18.48  17.97
# 4  Ahmedabad 2015-01-05  67.450578  118.127103  22.10  21.42  37.76
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0  23.483476   0.92  27.64  133.36     0.00     0.02    0.00  166.463581
# 1  23.483476   0.97  24.55   34.06     3.68     5.50    3.77  166.463581
# 2  23.483476  17.40  29.07   30.70     6.80    16.40    2.25  166.463581
# 3  23.483476   1.70  18.59   36.08     4.43    10.14    1.00  166.463581
# 4  23.483476  22.10  39.33   39.31     7.01    18.89    2.78  166.463581
#
#   AQI_Bucket Month  Year
# 0   Moderate   Jan  2015
# 1   Moderate   Jan  2015
# 2   Moderate   Jan  2015
# ...

# %%
print(f'Total rows: {data.shape[0]}\nTotal Cols : {data.shape[1]}')
# Out:
# Total rows: 29531
# Total Cols : 18

# %% [markdown]
# ### **Value count for cities**

# %%
data['City'].value_counts()
# Out:
# City
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Bengaluru             2009
# Lucknow               2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: count, dtype: int64

# %% [markdown]
# ## **1.Analysis of AQI Bucket**

# %% [markdown]
# ### **Counting AQI Bucket**

# %%
data['AQI_Bucket'].value_counts()
# Out:
# AQI_Bucket
# Moderate        13510
# Satisfactory     8224
# Poor             2781
# Very Poor        2337
# Good             1341
# Severe           1338
# Name: count, dtype: int64

# %% [markdown]
# ### **Plotting Graph for AQI Bucket**

# %%
aqi_buckets_count = data['AQI_Bucket'].value_counts()
plt.figure(figsize=(10, 6))
aqi_buckets_count.plot(kind='bar', color='skyblue')
plt.title('Count of AQI Buckets')
plt.xlabel('AQI Bucket')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## **2.Analysis of AQI**

# %% [markdown]
# ### **Plotting graph for AQI**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['AQI'], bins=30, kde=True, color='blue')
plt.title('Distribution of Air Quality Index (AQI)')
plt.xlabel('AQI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### **Group data by month and year for AQI**

# %%
AQI_trends = data.groupby('Month'and'Year')['AQI'].mean().reset_index()
AQI_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plotting Graph for Seasonal Trends in AQI Over the Years**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='AQI', hue='Year', data=AQI_trends, palette='Set1')
plt.title('Seasonal Trends in AQI Over the Years')
plt.xlabel('Month')
plt.ylabel('AQI')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ### **Plot seasonal trends in AQI over the months**

# %%
seasonal_trends = data.groupby('Month' and 'Year')['AQI'].mean()


plt.figure(figsize=(14, 6))
plt.plot(seasonal_trends.index, seasonal_trends.values, marker='o', linestyle='-', color='green')
plt.title('seasonal trends in AQI over the months')
plt.xlabel('Month')
plt.ylabel('AQI')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **3.Pollution spikes**

# %% [markdown]
# ### **Group data by City for AQI**

# %%
city_trends = data.groupby('City')['AQI'].mean()
city_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot AQI over time to identify spikes**

# %%
### Identify Pollution Spikes and Potential Causes ###
plt.figure(figsize=(14, 7))
sns.lineplot(x='Date', y='AQI', data=city_trends, hue='City')
plt.title('Daily AQI Over Time Across Cities')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.legend(title='City', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## **4.AQI by Cities and their Comparison**

# %% [markdown]
# ### **For specific city analysis**

# %%
city_name = 'Delhi'  # Change this to any city in your dataset
city_data = data[data['City'] == city_name]

# %% [markdown]
# ### **Plot pollution levels for Delhi**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='AQI', data=city_data)
plt.title(f'AQI in {city_name} Over Time')  # Using f-string to include city_name
plt.xlabel('Date')
plt.ylabel('AQI')
plt.show()

# %% [markdown]
# ### **Compare AQI Between Cities**

# %% [markdown]
# ### **Calculate the average AQI for each city**

# %%
city_comparison = data.groupby('City')['AQI'].mean().reset_index()
# Sort by AQI values
city_comparison = city_comparison.sort_values(by='AQI', ascending=False)

# %% [markdown]
# ### **Plot Graph for Comparison b/w  AQI of Cities**

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x='AQI', y='City', data=city_comparison, palette='coolwarm', hue='AQI')
plt.title('Comparison b/w  AQI of Cities')
plt.xlabel('AQI')
plt.ylabel('City')
plt.legend(title='AQI')  # Optional: Add a legend title
plt.show()

# %% [markdown]
# ## **5.Analysis of pollutant**

# %% [markdown]
# ### **Group data by month and year for PM2.5**

# %%
pm25_trends = data.groupby('Month'and'Year')['PM2.5'].mean().reset_index()
pm25_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph for Seasonal Trends in PM2.5 Levels**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='PM2.5', hue='Year', data=pm25_trends, palette='Set1')
plt.title('Seasonal Trends in PM2.5 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('PM2.5')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ### **Group data by month and year for PM10**

# %%
pm10_trends = data.groupby('Month'and'Year')['PM2.5'].mean().reset_index()
pm10_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph for Seasonal Trends in PM10 Levels Over the Month**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='PM10', hue='Year', data=pm10_trends, palette='Set1')
plt.title('Seasonal Trends in PM10 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('PM10')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ### **Group data by month and year for NO2**

# %%
NO2_trends = data.groupby('Month'and'Year')['NO2'].mean().reset_index()
NO2_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph for Seasonal Trends in NO2**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='NO2', hue='Year', data=NO2_trends, palette='Set1')
plt.title('Seasonal Trends in NO2 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('NO2')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ### **Group data by month and year for SO2**

# %%
SO2_trends = data.groupby('Month'and'Year')['SO2'].mean().reset_index()
SO2_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph for Seasonal Trends in SO2**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='SO2', hue='Year', data=SO2_trends, palette='Set1')
plt.title('Seasonal Trends in SO2 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('SO2')
plt.legend(title='Year', loc='upper right')
plt.show()

# %% [markdown]
# ### **Group data by month and year for NH3**

# %%
NH3_trends = data.groupby('Month'and'Year')['NH3'].mean().reset_index()
NH3_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph by Seasonal Trends in NH3 Levels**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='NH3', hue='Year', data=NH3_trends, palette='Set1')
plt.title('Seasonal Trends in NH3 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('NH3')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ### **Group data by month and year for O3**

# %%
O3_trends = data.groupby('Month'and 'Year')['O3'].mean().reset_index()
O3_trends = pd.DataFrame(data)

# %% [markdown]
# ### **Plot Graph for Seasonal Trends in 03 Levels**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='O3', hue='Year', data=O3_trends, palette='Set1')
plt.title('Seasonal Trends in 03 Levels Over the Years')
plt.xlabel('Month')
plt.ylabel('O3')
plt.legend(title='Year', loc='lower right')
plt.show()

# %% [markdown]
# ## **6.Correlation between Pollutants**

# %% [markdown]
# ### **Compute the correlation matrix for pollutants**

# %%
pollutant_columns = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
correlation_matrix = data[pollutant_columns].corr()

# %% [markdown]
# ### **Plot heatmap for the correlation between pollutants**

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Between Pollutants')
plt.show()

# %%
data.to_csv('city_day_transformed.csv',index=False)
